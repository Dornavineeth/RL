# %%
import json
import matplotlib.pyplot as plt
import numpy as np

def load_data(file_paths):
    """
    Load data from given file paths.
    """
    data = {}
    for path in file_paths:
        with open(path, 'r') as file:
            data[path] = json.load(file)
    return data

def plot_data_connected(file_data, x_label, title, save_path):
    """
    Plots the mean and variance of the total rewards for each experiment setting,
    connecting the dots with a line.

    Args:
    - file_data: The data from one of the JSON files.
    - title: The title for the plot.
    """
    experiment_settings = list(file_data.keys())
    rewards = {setting: [details['total_reward'] for details in file_data[setting].values()] for setting in experiment_settings}
    means = [np.mean(rewards[setting]) for setting in experiment_settings]
    variances = [np.var(rewards[setting]) for setting in experiment_settings]

    plt.figure(figsize=(10, 6))
    plt.errorbar(experiment_settings, means, yerr=np.sqrt(variances), fmt='o-', ecolor='red', capsize=5)
    plt.xlabel(x_label)
    plt.ylabel('Average Total Return')
    plt.title(title)
    plt.grid(True)
    plt.savefig(save_path)
    plt.show()

# %%
# File paths for the JSON files
file_paths = [
    'results/mcts/cartpole_budgets.json',
    'results/mcts/cartpole_depths.json',
    'results/mcts/gridworld_budgets.json',
    'results/mcts/gridworld_depths.json'
]
save_paths = [
    'plots/cartpole_budgets.png',
    'plots/cartpole_depths.png',
    'plots/gridworld_budgets.png',
    'plots/gridworld_depths.png'
]
x_labels = ["Budget", "Depth", "Budget", "Depth"]
titles = ["CartPole - Budget", "CartPole - Depth", "GridWorld - Budget", "GridWorld - Depth"]

# Load the data
data = load_data(file_paths)

for file_data,x_label, titles, save_path in zip(data.values(), x_labels, titles, save_paths):
    plot_data_connected(file_data, x_label, titles, save_path)

# %%
env = gym.make('CartPole-v1')

# %%
env.action_space
# Out:
# Discrete(2)

# %%
env.reset()
# Out:
# (array([ 0.0044832 , -0.04559373, -0.00801097,  0.04841718], dtype=float32),
#  {})

# %%
env.action_space.sample()
# Out:
# 1

# %%
env.step(env.action_space.sample())
# Out:
# (array([-5.0901672e-05,  1.5013713e-01, -3.7261245e-03, -2.5769842e-01],
#        dtype=float32),
#  1.0,
#  False,
#  False,
#  {})

# %%
env.observation_space
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %%
env.observation_space.high
# Out:
# array([4.8000002e+00, 3.4028235e+38, 4.1887903e-01, 3.4028235e+38],
#       dtype=float32)

# %%
env.observation_space.low
# Out:
# array([-4.8000002e+00, -3.4028235e+38, -4.1887903e-01, -3.4028235e+38],
#       dtype=float32)

# %%
from environment.gridworld import TwoDGridWorld
# Out:
# Running cells with '/usr/bin/python3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
from environment import TwoDGridWorld
import copy
import numpy as np

# %%
# np.randon.seed(0)
env = TwoDGridWorld()
observation = env.reset()
print(observation)
observation, reward, terminated, info = env.step(0)
print(observation)
# terminated = False
# states_traj = []
# actions_traj = []
# while not terminated:
#     states_traj.append(observation)
#     action = 
#     actions_traj.append(action)
#     observation, reward, terminated, info = env.step(action)
# Out:
# [0]
# [0]

# %%
env_copy.agent_position
# Out:
# 2
